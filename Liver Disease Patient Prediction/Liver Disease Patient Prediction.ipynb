# %%
import pandas as pd
import numpy as np
import matplotlib as plt 
import seaborn as sns 

import keras
import tensorflow as tf #library
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import keras.models as km #framework
from keras.models import Sequential
from keras import activations, initializers, regularizers, constraints #regularizers - panelty and loss 
from keras.layers import Dense, Activation

# %%
df = pd.read_csv("./data/indian_liver_patient.csv")

# %%
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
df.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# ...

# %%
df.describe().round()
# Out:
#          Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.0            583.0             583.0                 583.0
# mean    45.0              3.0               1.0                 291.0
# std     16.0              6.0               3.0                 243.0
# min      4.0              0.0               0.0                  63.0
# 25%     33.0              1.0               0.0                 176.0
# 50%     45.0              1.0               0.0                 208.0
# 75%     58.0              3.0               1.0                 298.0
# max     90.0             75.0              20.0                2110.0
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                     583.0                       583.0           583.0
# mean                       81.0                       110.0             6.0
# std                       183.0                       289.0             1.0
# ...

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
df.shape
# Out:
# (583, 11)

# %%
df['Albumin_and_Globulin_Ratio'].unique()
# Out:
# array([0.9 , 0.74, 0.89, 1.  , 0.4 , 1.3 , 1.1 , 1.2 , 0.8 , 0.6 , 0.87,
#        0.7 , 0.92, 0.55, 0.5 , 1.85, 0.95, 1.4 , 1.18, 0.61, 1.34, 1.39,
#        1.6 , 1.58, 1.25, 0.78, 0.76, 1.55, 0.71, 0.62, 0.67, 0.75, 1.16,
#        1.5 , 1.66, 0.96, 1.38, 0.52, 0.47, 0.93, 0.48, 0.58, 0.69, 1.27,
#        1.12, 1.06, 0.53, 1.03, 0.68,  nan, 1.9 , 1.7 , 1.8 , 0.3 , 0.97,
#        0.35, 1.51, 0.64, 0.45, 1.36, 0.88, 1.09, 1.11, 1.72, 2.8 , 0.46,
#        0.39, 1.02, 2.5 , 0.37])

# %%
df['Albumin_and_Globulin_Ratio'] = df['Albumin_and_Globulin_Ratio'].fillna(df['Albumin_and_Globulin_Ratio'].mean())

# %%
df['Albumin_and_Globulin_Ratio'].dtype
# Out:
# dtype('float64')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    str
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  583 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), str(1)
# memory usage: 52.8 KB

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      441
# Female    142
# Name: count, dtype: int64

# %%
df['Gender'] = df['Gender'].replace({'Male':0,'Female':1})

# %%
df['Gender'].value_counts()
df['Gender'] = df['Gender'].astype('int64')

# %%
df['Dataset'].value_counts()
# Out:
# Dataset
# 1    416
# 2    167
# Name: count, dtype: int64

# %%
df['Dataset'] = df['Dataset'].replace({2 : 0})
df['Dataset'].value_counts()
# Out:
# Dataset
# 1    416
# 0    167
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    int64
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  583 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(6)
# memory usage: 50.2 KB

# %%
X = df.drop(columns=['Dataset'])
y = df['Dataset']
print(X.shape)
print(y.shape)
# Out:
# (583, 10)
# (583,)

# %%
train_X,test_X,train_y,test_y = train_test_split(X,y,test_size=0.3,random_state=42)
print(train_X.shape)
print(train_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (408, 10)
# (408,)
# (175, 10)
# (175,)

# %%
model = Sequential()
model.add(Dense(units = 10, kernel_initializer = 'uniform', activation = 'relu', input_dim = 10))
model.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu')) #relu - rectify linear unit 
model.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu')) #units - 2^n
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'linear'))
# Out:
# C:\Users\Roshan\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary() # sequential : like a structure
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 10)                  │             110 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 6)                   │              66 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 4)                   │              28 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               5 │
# ...

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model.fit(train_X, train_y, epochs=50, batch_size=32, validation_split=0.1)

# Evaluate the model
mse = model.evaluate(test_X, test_y)
print(f'Test Mean Squared Error: {mse}')
# Out:
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.6993 - val_loss: 0.6625
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6744 - val_loss: 0.6332
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6320 - val_loss: 0.5781
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5429 - val_loss: 0.4663
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4070 - val_loss: 0.3043
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3089 - val_loss: 0.2346
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3048 - val_loss: 0.2223
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2897 - val_loss: 0.2293
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2812 - val_loss: 0.2322
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2734 - val_loss: 0.2177
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2668 - val_loss: 0.2209
# Epoch 12/50
# ...

# %%
predictions = model.predict(test_X)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
import joblib

# %%
joblib.dump(model, "model.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# import streamlit as st
# import joblib
# import numpy as np
#
# # Load model
# model = joblib.load("model.pkl")
#
# st.title("Machine Learning Prediction")
#
# st.write("Enter the required values")
#
# feature1 = st.number_input("Feature 1")
# feature2 = st.number_input("Feature 2")
# feature3 = st.number_input("Feature 3")
# feature4 = st.number_input("Feature 4")
#
# if st.button("Predict"):
#
#     input_data = np.array([
#         [feature1, feature2, feature3, feature4]
#     ])
#
#     prediction = model.predict(input_data)
#
#     st.success(f"Prediction: {prediction[0]}")

# %%
 model.save("model.keras")

# %%
from tensorflow import keras

loaded_model = keras.models.load_model(
    "model.keras",
    compile=False
)

print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
prediction = loaded_model.predict(
    test_X[:1],
    verbose=0
)

print(prediction)
# Out:
# [[0.4888153]]
